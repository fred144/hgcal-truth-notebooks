# %%
import devhgcaltruth as ht
import uptools
import uproot
import numpy as np

# %%
# ntup = '/home/sys-ad/Desktop/phys165/hgcalNtuple_1000_1.root'
# event = uptools.get_event_rootfile(ntup, 100)
# event['gunparticle_id']

# %%
ntuple = uproot.open('/home/sys-ad/Desktop/phys165/hgcalNtuple_1000_1.root')
events = ntuple['ana/hgc']
events.show()
# Out:
# name                 | typename                 | interpretation
# ---------------------+--------------------------+-------------------------------
# event                | uint64_t                 | AsDtype('>u8')
# lumi                 | uint32_t                 | AsDtype('>u4')
# run                  | uint32_t                 | AsDtype('>u4')
# vtx_x                | float                    | AsDtype('>f4')
# vtx_y                | float                    | AsDtype('>f4')
# vtx_z                | float                    | AsDtype('>f4')
# genpart_eta          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_phi          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_pt           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_energy       | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_dvx          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_dvy          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_dvz          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_ovx          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_ovy          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_ovz          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_mother       | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# genpart_exphi        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_exeta        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_exx          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_exy          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_fbrem        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# genpart_pid          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# genpart_gen          | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# genpart_reachedEE    | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# genpart_fromBeamPipe | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# genpart_posx         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# genpart_posy         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# genpart_posz         | std::vector<std::vect... | AsObjects(AsVector(True, As...
# gen_eta              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# gen_phi              | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# gen_pt               | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# gen_energy           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# gen_charge           | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# gen_pdgid            | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# gen_status           | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# gen_daughters        | std::vector<std::vect... | AsObjects(AsVector(True, As...
# rechit_eta           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# rechit_phi           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# rechit_pt            | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# rechit_energy        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# rechit_x             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# rechit_y             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# rechit_z             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# rechit_time          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# rechit_thickness     | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# rechit_layer         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# rechit_wafer_u       | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# rechit_wafer_v       | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# rechit_cell_u        | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# rechit_cell_v        | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# rechit_detid         | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# rechit_isHalf        | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# rechit_flags         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# rechit_cluster2d     | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# rechit_radius        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simhit_eta           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simhit_phi           | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simhit_energy        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simhit_x             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simhit_y             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simhit_z             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simhit_layer         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# simhit_wafer_u       | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# simhit_wafer_v       | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# simhit_cell_u        | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# simhit_cell_v        | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# simhit_detid         | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# simhit_isHalf        | std::vector<bool>        | AsJagged(AsDtype('bool'), h...
# simhit_flags         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cluster2d_eta        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cluster2d_phi        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cluster2d_pt         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cluster2d_energy     | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cluster2d_x          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cluster2d_y          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cluster2d_z          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# cluster2d_layer      | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cluster2d_nhitCore   | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cluster2d_nhitAll    | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cluster2d_multicl... | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# cluster2d_rechits    | std::vector<std::vect... | AsObjects(AsVector(True, As...
# cluster2d_rechitSeed | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# multiclus_eta        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# multiclus_phi        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# multiclus_pt         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# multiclus_energy     | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# multiclus_z          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# multiclus_slopeX     | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# multiclus_slopeY     | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# multiclus_cluster2d  | std::vector<std::vect... | AsObjects(AsVector(True, As...
# multiclus_cl2dSeed   | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# multiclus_firstLay   | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# multiclus_lastLay    | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# multiclus_NLay       | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# simcluster_eta       | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simcluster_phi       | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simcluster_pt        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simcluster_energy    | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simcluster_simEnergy | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# simcluster_hits      | std::vector<std::vect... | AsObjects(AsVector(True, As...
# simcluster_hits_i... | std::vector<std::vect... | AsObjects(AsVector(True, As...
# simcluster_fractions | std::vector<std::vect... | AsObjects(AsVector(True, As...
# simcluster_layers    | std::vector<std::vect... | AsObjects(AsVector(True, As...
# simcluster_wafers_u  | std::vector<std::vect... | AsObjects(AsVector(True, As...
# simcluster_wafers_v  | std::vector<std::vect... | AsObjects(AsVector(True, As...
# simcluster_cells_u   | std::vector<std::vect... | AsObjects(AsVector(True, As...
# simcluster_cells_v   | std::vector<std::vect... | AsObjects(AsVector(True, As...
# pfcluster_eta        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfcluster_phi        | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfcluster_pt         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfcluster_energy     | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfcluster_correct... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfcluster_hits       | std::vector<std::vect... | AsObjects(AsVector(True, As...
# pfcluster_fractions  | std::vector<std::vect... | AsObjects(AsVector(True, As...
# pfclusterFromMult... | vector<ROOT::Math::Po... | AsGroup(<TBranchElement 'pf...
# pfclusterFromMult... | double[]                 | AsJagged(AsDtype('>f8'))
# pfclusterFromMult... | double[]                 | AsJagged(AsDtype('>f8'))
# pfclusterFromMult... | double[]                 | AsJagged(AsDtype('>f8'))
# pfclusterFromMult... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfclusterFromMult... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfclusterFromMult... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfclusterFromMult... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfclusterFromMult... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfclusterFromMult... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfclusterFromMult... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfclusterFromMult... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfclusterFromMult... | std::vector<std::vect... | AsObjects(AsVector(True, As...
# pfclusterFromMult... | std::vector<std::vect... | AsObjects(AsVector(True, As...
# pfclusterFromMult... | std::vector<std::vect... | AsObjects(AsVector(True, As...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_eta | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_phi | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_pt  | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | vector<ROOT::Math::Po... | AsGroup(<TBranchElement 'ec...
# ecalDrivenGsfele_... | double[]                 | AsJagged(AsDtype('>f8'))
# ecalDrivenGsfele_... | double[]                 | AsJagged(AsDtype('>f8'))
# ecalDrivenGsfele_... | double[]                 | AsJagged(AsDtype('>f8'))
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<uint32_t>    | AsJagged(AsDtype('>u4'), he...
# ecalDrivenGsfele_... | vector<ROOT::Math::Po... | AsGroup(<TBranchElement 'ec...
# ecalDrivenGsfele_... | double[]                 | AsJagged(AsDtype('>f8'))
# ecalDrivenGsfele_... | double[]                 | AsJagged(AsDtype('>f8'))
# ecalDrivenGsfele_... | double[]                 | AsJagged(AsDtype('>f8'))
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_hoe | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# ecalDrivenGsfele_... | std::vector<std::vect... | AsObjects(AsVector(True, As...
# calopart_eta         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# calopart_phi         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# calopart_pt          | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# calopart_energy      | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# calopart_simEnergy   | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# calopart_simClust... | std::vector<std::vect... | AsObjects(AsVector(True, As...
# track_eta            | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# track_phi            | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# track_pt             | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# track_energy         | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# track_charge         | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# track_posx           | std::vector<std::vect... | AsObjects(AsVector(True, As...
# track_posy           | std::vector<std::vect... | AsObjects(AsVector(True, As...
# track_posz           | std::vector<std::vect... | AsObjects(AsVector(True, As...
# pfcandidate_eta      | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfcandidate_phi      | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfcandidate_pt       | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfcandidate_energy   | std::vector<float>       | AsJagged(AsDtype('>f4'), he...
# pfcandidate_pdgid    | std::vector<int32_t>     | AsJagged(AsDtype('>i4'), he...
# gunparticle_id       | std::vector<std::vect... | AsObjects(AsVector(True, As...
# gunparticle_energy   | std::vector<std::vect... | AsObjects(AsVector(True, As...
# gunparticle_pt       | std::vector<std::vect... | AsObjects(AsVector(True, As...
# gunparticle_eta      | std::vector<std::vect... | AsObjects(AsVector(True, As...
# gunparticle_phi      | std::vector<std::vect... | AsObjects(AsVector(True, As...

# %%
events["genpart_energy"].array()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_4472/3652149961.py in <module>
# ----> 1 events["genpart_energy"].array()
#
# ~/anaconda3/envs/phys165/lib/python3.8/site-packages/uproot/behaviors/TBranch.py in array(self, interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library)
#    2093                         ranges_or_baskets.append((branch, basket_num, range_or_basket))
#    2094
# -> 2095         _ranges_or_baskets_to_arrays(
#    2096             self,
#    2097             ranges_or_baskets,
#
# ~/anaconda3/envs/phys165/lib/python3.8/site-packages/uproot/behaviors/TBranch.py in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets)
#    3508
#    3509         elif isinstance(obj, tuple) and len(obj) == 3:
# -> 3510             uproot.source.futures.delayed_raise(*obj)
#    3511
#    3512         else:
#
# ~/anaconda3/envs/phys165/lib/python3.8/site-packages/uproot/source/futures.py in delayed_raise(exception_class, exception_value, traceback)
#      44         exec("raise exception_class, exception_value, traceback")
#      45     else:
# ---> 46         raise exception_value.with_traceback(traceback)
#      47
#      48
#
# ~/anaconda3/envs/phys165/lib/python3.8/site-packages/uproot/behaviors/TBranch.py in basket_to_array(basket)
#    3478
#    3479             if len(basket_arrays) == branchid_num_baskets[branch.cache_key]:
# -> 3480                 arrays[branch.cache_key] = interpretation.final_array(
#    3481                     basket_arrays,
#    3482                     entry_start,
#
# ~/anaconda3/envs/phys165/lib/python3.8/site-packages/uproot/interpretation/jagged.py in final_array(self, basket_arrays, entry_start, entry_stop, entry_offsets, library, branch)
#     317             )
#     318
# --> 319         output = library.finalize(output, branch, self, entry_start, entry_stop)
#     320
#     321         self.hook_after_final_array(
#
# ~/anaconda3/envs/phys165/lib/python3.8/site-packages/uproot/interpretation/library.py in finalize(self, array, branch, interpretation, entry_start, entry_stop)
#     495
#     496     def finalize(self, array, branch, interpretation, entry_start, entry_stop):
# --> 497         awkward = self.imported
#     498
#     499         if isinstance(array, awkward.layout.Content):
#
# ~/anaconda3/envs/phys165/lib/python3.8/site-packages/uproot/interpretation/library.py in imported(self)
#     492     @property
#     493     def imported(self):
# --> 494         return uproot.extras.awkward()
#     495
#     496     def finalize(self, array, branch, interpretation, entry_start, entry_stop):
#
# ~/anaconda3/envs/phys165/lib/python3.8/site-packages/uproot/extras.py in awkward()
#      37         return awkward
#      38     else:
# ---> 39         raise ImportError(
#      40             "Uproot 4.x can only be used with Awkward 1.x; you have Awkward {0}".format(
#      41                 awkward.__version__
#
# ImportError: Uproot 4.x can only be used with Awkward 1.x; you have Awkward 0.14.0
